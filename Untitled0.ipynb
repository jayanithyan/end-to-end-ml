# %% [markdown]
# <a href="https://colab.research.google.com/github/jayanithyan/end-to-end-ml/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/modified_placement_data (1).csv')

# %%
df.head()
# Out:
#   cgpa     iq placement
# 0  6,8  123.0       Yes
# 1  5,9  106.0        No
# 2  5,3  121.0        No
# 3  7,4  132.0       Yes
# 4  5,8  142.0        No

# %%
df.shape
# Out:
# (100, 2)

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#       iq placement
# 0  123.0       Yes
# 1  106.0        No
# 2  121.0        No
# 3  132.0       Yes
# 4  142.0        No
